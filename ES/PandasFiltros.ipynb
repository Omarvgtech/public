# %%
import pandas

# %%
pandas.__version__
# Out:
# '2.0.3'

# %%
import pandas as pan

# %%
pan.__version__
# Out:
# '2.0.3'

# %%
pan.show_versions()
# Out:
# INSTALLED VERSIONS
# ------------------
# commit           : 0f437949513225922d851e9581723d82120684a6
# python           : 3.11.4.final.0
# python-bits      : 64
# OS               : Windows
# OS-release       : 10
# Version          : 10.0.22621
# machine          : AMD64
# processor        : Intel64 Family 6 Model 165 Stepping 2, GenuineIntel
# byteorder        : little
# LC_ALL           : None
# LANG             : None
# LOCALE           : Spanish_Mexico.1252
#
# pandas           : 2.0.3
# numpy            : 1.25.2
# pytz             : 2023.3
# dateutil         : 2.8.2
# setuptools       : 65.5.0
# pip              : 23.1.2
# Cython           : None
# pytest           : None
# hypothesis       : None
# sphinx           : None
# blosc            : None
# feather          : None
# xlsxwriter       : None
# lxml.etree       : None
# html5lib         : None
# pymysql          : None
# psycopg2         : None
# jinja2           : 3.1.2
# IPython          : 8.14.0
# ...

# %%
for x in dir(pandas):
    print(x)
# Out:
# ArrowDtype
# BooleanDtype
# Categorical
# CategoricalDtype
# CategoricalIndex
# DataFrame
# DateOffset
# DatetimeIndex
# DatetimeTZDtype
# ExcelFile
# ExcelWriter
# Flags
# Float32Dtype
# Float64Dtype
# Grouper
# HDFStore
# Index
# IndexSlice
# Int16Dtype
# Int32Dtype
# Int64Dtype
# Int8Dtype
# Interval
# IntervalDtype
# IntervalIndex
# MultiIndex
# NA
# NaT
# NamedAgg
# Period
# PeriodDtype
# PeriodIndex
# RangeIndex
# Series
# SparseDtype
# StringDtype
# Timedelta
# TimedeltaIndex
# Timestamp
# UInt16Dtype
# UInt32Dtype
# UInt64Dtype
# UInt8Dtype
# __all__
# __builtins__
# __cached__
# __doc__
# __docformat__
# __file__
# __git_version__
# __loader__
# __name__
# __package__
# __path__
# __spec__
# __version__
# _config
# _is_numpy_dev
# _libs
# _testing
# _typing
# _version
# annotations
# api
# array
# arrays
# bdate_range
# compat
# concat
# core
# crosstab
# cut
# date_range
# describe_option
# errors
# eval
# factorize
# from_dummies
# get_dummies
# get_option
# infer_freq
# ...

# %%
pan.read_csv?
# Out:
# Signature:
# pan.read_csv(
#     filepath_or_buffer: 'FilePath | ReadCsvBuffer[bytes] | ReadCsvBuffer[str]',
#     *,
#     sep: 'str | None | lib.NoDefault' = <no_default>,
#     delimiter: 'str | None | lib.NoDefault' = None,
#     header: "int | Sequence[int] | None | Literal['infer']" = 'infer',
#     names: 'Sequence[Hashable] | None | lib.NoDefault' = <no_default>,
#     index_col: 'IndexLabel | Literal[False] | None' = None,
#     usecols=None,
#     dtype: 'DtypeArg | None' = None,
#     engine: 'CSVEngine | None' = None,
#     converters=None,
#     true_values=None,
#     false_values=None,
#     skipinitialspace: 'bool' = False,
#     skiprows=None,
#     skipfooter: 'int' = 0,
#     nrows: 'int | None' = None,
#     na_values=None,
#     keep_default_na: 'bool' = True,
#     na_filter: 'bool' = True,
#     verbose: 'bool' = False,
#     skip_blank_lines: 'bool' = True,
#     parse_dates: 'bool | Sequence[Hashable] | None' = None,
# ...

# %%
data=pan.read_csv('C:/ejercicios/olympics.csv',skiprows=4)

# %%
data.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
data
# Out:
#           City  Edition      Sport       Discipline               Athlete  \
# 0       Athens     1896   Aquatics         Swimming         HAJOS, Alfred
# 1       Athens     1896   Aquatics         Swimming      HERSCHMANN, Otto
# 2       Athens     1896   Aquatics         Swimming     DRIVAS, Dimitrios
# 3       Athens     1896   Aquatics         Swimming    MALOKINIS, Ioannis
# 4       Athens     1896   Aquatics         Swimming    CHASAPIS, Spiridon
# ...        ...      ...        ...              ...                   ...
# 29211  Beijing     2008  Wrestling  Wrestling Gre-R        ENGLICH, Mirko
# 29212  Beijing     2008  Wrestling  Wrestling Gre-R  MIZGAITIS, Mindaugas
# 29213  Beijing     2008  Wrestling  Wrestling Gre-R       PATRIKEEV, Yuri
# 29214  Beijing     2008  Wrestling  Wrestling Gre-R         LOPEZ, Mijain
# 29215  Beijing     2008  Wrestling  Wrestling Gre-R        BAROEV, Khasan
#
#        NOC Gender                       Event Event_gender   Medal
# ...

# %%
data['Sport']
# Out:
# 0         Aquatics
# 1         Aquatics
# 2         Aquatics
# 3         Aquatics
# 4         Aquatics
#            ...
# 29211    Wrestling
# 29212    Wrestling
# 29213    Wrestling
# 29214    Wrestling
# 29215    Wrestling
# Name: Sport, Length: 29216, dtype: object

# %%
data['Medal']
# Out:
# 0          Gold
# 1        Silver
# 2        Bronze
# 3          Gold
# 4        Silver
#           ...
# 29211    Silver
# 29212    Bronze
# 29213    Bronze
# 29214      Gold
# 29215    Silver
# Name: Medal, Length: 29216, dtype: object

# %%
data['NOC']
# Out:
# 0        HUN
# 1        AUT
# 2        GRE
# 3        GRE
# 4        GRE
#         ...
# 29211    GER
# 29212    LTU
# 29213    ARM
# 29214    CUB
# 29215    RUS
# Name: NOC, Length: 29216, dtype: object

# %%
data.Medal
# Out:
# 0          Gold
# 1        Silver
# 2        Bronze
# 3          Gold
# 4        Silver
#           ...
# 29211    Silver
# 29212    Bronze
# 29213    Bronze
# 29214      Gold
# 29215    Silver
# Name: Medal, Length: 29216, dtype: object

# %%
data.NOC
# Out:
# 0        HUN
# 1        AUT
# 2        GRE
# 3        GRE
# 4        GRE
#         ...
# 29211    GER
# 29212    LTU
# 29213    ARM
# 29214    CUB
# 29215    RUS
# Name: NOC, Length: 29216, dtype: object

# %%
type(data.Medal)
# Out:
# pandas.core.series.Series

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data[['Medal','Sport','Athlete']]
# Out:
#         Medal      Sport               Athlete
# 0        Gold   Aquatics         HAJOS, Alfred
# 1      Silver   Aquatics      HERSCHMANN, Otto
# 2      Bronze   Aquatics     DRIVAS, Dimitrios
# 3        Gold   Aquatics    MALOKINIS, Ioannis
# 4      Silver   Aquatics    CHASAPIS, Spiridon
# ...       ...        ...                   ...
# 29211  Silver  Wrestling        ENGLICH, Mirko
# 29212  Bronze  Wrestling  MIZGAITIS, Mindaugas
# 29213  Bronze  Wrestling       PATRIKEEV, Yuri
# 29214    Gold  Wrestling         LOPEZ, Mijain
# 29215  Silver  Wrestling        BAROEV, Khasan
#
# [29216 rows x 3 columns]

# %%
data.shape
# Out:
# (29216, 10)

# %%
data.shape[0]
# Out:
# 29216

# %%
data.head(3)
# Out:
#      City  Edition     Sport Discipline            Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming      HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming   HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming  DRIVAS, Dimitrios  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze

# %%
data.head(10)
# Out:
#      City  Edition     Sport Discipline                Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming          HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming       HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming      DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming     MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming     CHASAPIS, Spiridon  GRE    Men
# 5  Athens     1896  Aquatics   Swimming  CHOROPHAS, Efstathios  GRE    Men
# 6  Athens     1896  Aquatics   Swimming          HAJOS, Alfred  HUN    Men
# 7  Athens     1896  Aquatics   Swimming       ANDREOU, Joannis  GRE    Men
# 8  Athens     1896  Aquatics   Swimming  CHOROPHAS, Efstathios  GRE    Men
# 9  Athens     1896  Aquatics   Swimming          NEUMANN, Paul  AUT    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# ...

# %%
data.head(100)
# Out:
#       City  Edition       Sport   Discipline               Athlete  NOC  \
# 0   Athens     1896    Aquatics     Swimming         HAJOS, Alfred  HUN
# 1   Athens     1896    Aquatics     Swimming      HERSCHMANN, Otto  AUT
# 2   Athens     1896    Aquatics     Swimming     DRIVAS, Dimitrios  GRE
# 3   Athens     1896    Aquatics     Swimming    MALOKINIS, Ioannis  GRE
# 4   Athens     1896    Aquatics     Swimming    CHASAPIS, Spiridon  GRE
# ..     ...      ...         ...          ...                   ...  ...
# 95  Athens     1896  Gymnastics  Artistic G.   CHRYSAPHIS, Ioannis  GRE
# 96  Athens     1896  Gymnastics  Artistic G.  KARVELAS, Phillippos  GRE
# 97  Athens     1896  Gymnastics  Artistic G.   LOUNDRAS, Dimitrios  GRE
# 98  Athens     1896  Gymnastics  Artistic G.  MITROPOULOS, Ioannis  GRE
# 99  Athens     1896  Gymnastics  Artistic G.        BÖCKER, Konrad  GER
#
#    Gender                       Event Event_gender   Medal
# ...

# %%
data.tail()
# Out:
#           City  Edition      Sport       Discipline               Athlete  \
# 29211  Beijing     2008  Wrestling  Wrestling Gre-R        ENGLICH, Mirko
# 29212  Beijing     2008  Wrestling  Wrestling Gre-R  MIZGAITIS, Mindaugas
# 29213  Beijing     2008  Wrestling  Wrestling Gre-R       PATRIKEEV, Yuri
# 29214  Beijing     2008  Wrestling  Wrestling Gre-R         LOPEZ, Mijain
# 29215  Beijing     2008  Wrestling  Wrestling Gre-R        BAROEV, Khasan
#
#        NOC Gender       Event Event_gender   Medal
# 29211  GER    Men   84 - 96kg            M  Silver
# 29212  LTU    Men  96 - 120kg            M  Bronze
# 29213  ARM    Men  96 - 120kg            M  Bronze
# 29214  CUB    Men  96 - 120kg            M    Gold
# 29215  RUS    Men  96 - 120kg            M  Silver

# %%
data.tail(10)
# Out:
#           City  Edition      Sport       Discipline               Athlete  \
# 29206  Beijing     2008  Wrestling  Wrestling Gre-R      MINGUZZI, Andrea
# 29207  Beijing     2008  Wrestling  Wrestling Gre-R         FODOR, Zoltan
# 29208  Beijing     2008  Wrestling  Wrestling Gre-R       MAMBETOV, Asset
# 29209  Beijing     2008  Wrestling  Wrestling Gre-R         WHEELER, Adam
# 29210  Beijing     2008  Wrestling  Wrestling Gre-R    KHUSHTOV, Aslanbek
# 29211  Beijing     2008  Wrestling  Wrestling Gre-R        ENGLICH, Mirko
# 29212  Beijing     2008  Wrestling  Wrestling Gre-R  MIZGAITIS, Mindaugas
# 29213  Beijing     2008  Wrestling  Wrestling Gre-R       PATRIKEEV, Yuri
# 29214  Beijing     2008  Wrestling  Wrestling Gre-R         LOPEZ, Mijain
# 29215  Beijing     2008  Wrestling  Wrestling Gre-R        BAROEV, Khasan
#
#        NOC Gender       Event Event_gender   Medal
# 29206  ITA    Men   74 - 84kg            M    Gold
# 29207  HUN    Men   74 - 84kg            M  Silver
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29216 entries, 0 to 29215
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   City          29216 non-null  object
#  1   Edition       29216 non-null  int64
#  2   Sport         29216 non-null  object
#  3   Discipline    29216 non-null  object
#  4   Athlete       29216 non-null  object
#  5   NOC           29216 non-null  object
#  6   Gender        29216 non-null  object
#  7   Event         29216 non-null  object
#  8   Event_gender  29216 non-null  object
#  9   Medal         29216 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 2.2+ MB

# %%
data['City']
# Out:
# 0         Athens
# 1         Athens
# 2         Athens
# 3         Athens
# 4         Athens
#           ...
# 29211    Beijing
# 29212    Beijing
# 29213    Beijing
# 29214    Beijing
# 29215    Beijing
# Name: City, Length: 29216, dtype: object

# %%
data['City']
# Out:
# 0         Athens
# 1         Athens
# 2         Athens
# 3         Athens
# 4         Athens
#           ...
# 29211    Beijing
# 29212    Beijing
# 29213    Beijing
# 29214    Beijing
# 29215    Beijing
# Name: City, Length: 29216, dtype: object

# %%
data['City'].unique()
# Out:
# array(['Athens', 'Paris', 'St Louis', 'London', 'Stockholm', 'Antwerp',
#        'Amsterdam', 'Los Angeles', 'Berlin', 'Helsinki',
#        'Melbourne / Stockholm', 'Rome', 'Tokyo', 'Mexico', 'Munich',
#        'Montreal', 'Moscow', 'Seoul', 'Barcelona', 'Atlanta', 'Sydney',
#        'Beijing'], dtype=object)

# %%
data.Edition.value_counts()
# Out:
# Edition
# 2008    2042
# 2000    2015
# 2004    1998
# 1996    1859
# 1992    1705
# 1988    1546
# 1984    1459
# 1980    1387
# 1976    1305
# 1920    1298
# 1972    1185
# 1968    1031
# 1964    1010
# 1952     889
# 1912     885
# 1956     885
# 1924     884
# 1960     882
# 1936     875
# 1948     814
# 1908     804
# 1928     710
# 1932     615
# 1900     512
# 1904     470
# 1896     151
# Name: count, dtype: int64

# %%
data.City.value_counts()
# Out:
# City
# Athens                   2149
# Los Angeles              2074
# Beijing                  2042
# Sydney                   2015
# Atlanta                  1859
# Barcelona                1705
# London                   1618
# Seoul                    1546
# Paris                    1396
# Moscow                   1387
# Montreal                 1305
# Antwerp                  1298
# Munich                   1185
# Mexico                   1031
# Tokyo                    1010
# Helsinki                  889
# Stockholm                 885
# Melbourne / Stockholm     885
# Rome                      882
# Berlin                    875
# Amsterdam                 710
# St Louis                  470
# Name: count, dtype: int64

# %%
data.City.sort_values()
# Out:
# 5177     Amsterdam
# 5398     Amsterdam
# 5399     Amsterdam
# 5400     Amsterdam
# 5401     Amsterdam
#            ...
# 10737        Tokyo
# 10736        Tokyo
# 10735        Tokyo
# 10748        Tokyo
# 11623        Tokyo
# Name: City, Length: 29216, dtype: object

# %%
data.sort_values(by=['Edition','Medal'])
# Out:
#           City  Edition      Sport       Discipline                Athlete  \
# 2       Athens     1896   Aquatics         Swimming      DRIVAS, Dimitrios
# 5       Athens     1896   Aquatics         Swimming  CHOROPHAS, Efstathios
# 8       Athens     1896   Aquatics         Swimming  CHOROPHAS, Efstathios
# 11      Athens     1896  Athletics        Athletics          LANE, Francis
# 12      Athens     1896  Athletics        Athletics       SZOKOLYI, Alajos
# ...        ...      ...        ...              ...                    ...
# 29200  Beijing     2008  Wrestling  Wrestling Gre-R     BEGALIEV, Kanatbek
# 29204  Beijing     2008  Wrestling  Wrestling Gre-R       CHANG, Yongxiang
# 29207  Beijing     2008  Wrestling  Wrestling Gre-R          FODOR, Zoltan
# 29211  Beijing     2008  Wrestling  Wrestling Gre-R         ENGLICH, Mirko
# 29215  Beijing     2008  Wrestling  Wrestling Gre-R         BAROEV, Khasan
#
#        NOC Gender                       Event Event_gender   Medal
# ...

# %%
data[(data.Medal == 'Bronze') & (data.Gender=='Men')]
# Out:
#           City  Edition      Sport       Discipline                Athlete  \
# 2       Athens     1896   Aquatics         Swimming      DRIVAS, Dimitrios
# 5       Athens     1896   Aquatics         Swimming  CHOROPHAS, Efstathios
# 8       Athens     1896   Aquatics         Swimming  CHOROPHAS, Efstathios
# 11      Athens     1896  Athletics        Athletics          LANE, Francis
# 12      Athens     1896  Athletics        Athletics       SZOKOLYI, Alajos
# ...        ...      ...        ...              ...                    ...
# 29205  Beijing     2008  Wrestling  Wrestling Gre-R          AVLUCA, Nazmi
# 29208  Beijing     2008  Wrestling  Wrestling Gre-R        MAMBETOV, Asset
# 29209  Beijing     2008  Wrestling  Wrestling Gre-R          WHEELER, Adam
# 29212  Beijing     2008  Wrestling  Wrestling Gre-R   MIZGAITIS, Mindaugas
# 29213  Beijing     2008  Wrestling  Wrestling Gre-R        PATRIKEEV, Yuri
#
#        NOC Gender                       Event Event_gender   Medal
# ...

# %%
data[(data.Sport=='Tennis')]
# Out:
#           City  Edition   Sport Discipline                   Athlete  NOC  \
# 132     Athens     1896  Tennis     Tennis              FLACK, Edwin  ZZX
# 133     Athens     1896  Tennis     Tennis  ROBERTSON, George Stuart  ZZX
# 134     Athens     1896  Tennis     Tennis              BOLAND, John  ZZX
# 135     Athens     1896  Tennis     Tennis          TRAUN, Friedrich  ZZX
# 136     Athens     1896  Tennis     Tennis      KASDAGLIS, Dionysios  ZZX
# ...        ...      ...     ...        ...                       ...  ...
# 29005  Beijing     2008  Tennis     Tennis             NADAL, Rafael  ESP
# 29006  Beijing     2008  Tennis     Tennis        GONZALEZ, Fernando  CHI
# 29007  Beijing     2008  Tennis     Tennis           ZVONAREVA, Vera  RUS
# 29008  Beijing     2008  Tennis     Tennis         DEMENTIEVA, Elena  RUS
# 29009  Beijing     2008  Tennis     Tennis            SAFINA, Dinara  RUS
#
#       Gender    Event Event_gender   Medal
# ...

# %%
data[(data.Sport=='Tennis') & (data.Medal=='Silver') & (data.Gender=='Women')]
# Out:
#             City  Edition   Sport Discipline  \
# 642        Paris     1900  Tennis     Tennis
# 650        Paris     1900  Tennis     Tennis
# 1871      London     1908  Tennis     Tennis
# 1877      London     1908  Tennis     Tennis
# 2772   Stockholm     1912  Tennis     Tennis
# 2778   Stockholm     1912  Tennis     Tennis
# 2784   Stockholm     1912  Tennis     Tennis
# 2790   Stockholm     1912  Tennis     Tennis
# 4036     Antwerp     1920  Tennis     Tennis
# 4037     Antwerp     1920  Tennis     Tennis
# 4043     Antwerp     1920  Tennis     Tennis
# 4049     Antwerp     1920  Tennis     Tennis
# 4936       Paris     1924  Tennis     Tennis
# 4937       Paris     1924  Tennis     Tennis
# 4943       Paris     1924  Tennis     Tennis
# 4949       Paris     1924  Tennis     Tennis
# 19425      Seoul     1988  Tennis     Tennis
# 19426      Seoul     1988  Tennis     Tennis
# 19434      Seoul     1988  Tennis     Tennis
# 21131  Barcelona     1992  Tennis     Tennis
# ...

# %%
data[data.Athlete.str.contains('Pedro')]
# Out:
#             City  Edition       Sport  Discipline  \
# 3330     Antwerp     1920    Football    Football
# 4366       Paris     1924      Boxing      Boxing
# 4543       Paris     1924    Football    Football
# 4545       Paris     1924    Football    Football
# 4552       Paris     1924    Football    Football
# 5370   Amsterdam     1928    Football    Football
# 5371   Amsterdam     1928    Football    Football
# 5378   Amsterdam     1928    Football    Football
# 5385   Amsterdam     1928    Football    Football
# 7018      Berlin     1936      Rowing      Rowing
# 10424       Rome     1960      Hockey      Hockey
# 10434       Rome     1960      Hockey      Hockey
# 10435       Rome     1960      Hockey      Hockey
# 13051     Munich     1972  Basketball  Basketball
# 14315   Montreal     1976      Boxing      Boxing
# 14994   Montreal     1976     Sailing     Sailing
# 19233      Seoul     1988      Rowing      Rowing
# 19814  Barcelona     1992    Aquatics  Water polo
# ...

# %%
data
# Out:
#           City  Edition      Sport       Discipline               Athlete  \
# 0       Athens     1896   Aquatics         Swimming         HAJOS, Alfred
# 1       Athens     1896   Aquatics         Swimming      HERSCHMANN, Otto
# 2       Athens     1896   Aquatics         Swimming     DRIVAS, Dimitrios
# 3       Athens     1896   Aquatics         Swimming    MALOKINIS, Ioannis
# 4       Athens     1896   Aquatics         Swimming    CHASAPIS, Spiridon
# ...        ...      ...        ...              ...                   ...
# 29211  Beijing     2008  Wrestling  Wrestling Gre-R        ENGLICH, Mirko
# 29212  Beijing     2008  Wrestling  Wrestling Gre-R  MIZGAITIS, Mindaugas
# 29213  Beijing     2008  Wrestling  Wrestling Gre-R       PATRIKEEV, Yuri
# 29214  Beijing     2008  Wrestling  Wrestling Gre-R         LOPEZ, Mijain
# 29215  Beijing     2008  Wrestling  Wrestling Gre-R        BAROEV, Khasan
#
#        NOC Gender                       Event Event_gender   Medal
# ...

# %%
data['Medal'].values[0]
# Out:
# 'Gold'

# %%
data['Medal'].values[1]
# Out:
# 'Silver'

# %%
data[(data.Sport=='Football')]
# Out:
#           City  Edition     Sport Discipline            Athlete  NOC Gender  \
# 378      Paris     1900  Football   Football  DELBECQUE, Albert  BEL    Men
# 379      Paris     1900  Football   Football        KELECOM, R.  BEL    Men
# 380      Paris     1900  Football   Football   LEBOUTTE, Marcel  BEL    Men
# 381      Paris     1900  Football   Football             LONDOT  BEL    Men
# 382      Paris     1900  Football   Football     MOREAU, Ernest  BEL    Men
# ...        ...      ...       ...        ...                ...  ...    ...
# 28299  Beijing     2008  Football   Football           PRETINHA  BRA  Women
# 28300  Beijing     2008  Football   Football       RENATA COSTA  BRA  Women
# 28301  Beijing     2008  Football   Football             ROSANA  BRA  Women
# 28302  Beijing     2008  Football   Football             SIMONE  BRA  Women
# 28303  Beijing     2008  Football   Football              TANIA  BRA  Women
#
#           Event Event_gender   Medal
# ...
